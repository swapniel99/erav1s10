# %% [markdown]
# <a href="https://colab.research.google.com/github/swapniel99/erav1s10/blob/main/S10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/swapniel99/erav1s10.git
# %cd erav1s10/
# !git checkout .
# !git pull
# %ls
# Out:
# fatal: destination path 'erav1s10' already exists and is not an empty directory.
# /content/erav1s10
# Updated 0 paths from the index
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 446 bytes | 446.00 KiB/s, done.
# From https://github.com/swapniel99/erav1s10
#    ba38da9..d8c85a6  main       -> origin/main
# Updating ba38da9..d8c85a6
# Fast-forward
#  backprop.py | 7 +++++--
#  runner.py   | 5 ++---
#  2 files changed, 7 insertions(+), 5 deletions(-)
# assets/           datasets/     requirements.txt  summary.py
# backprop.py       __pycache__/  runner.py         utils.py
# custom_resnet.py  README.md     S10.ipynb

# %%
# !pip install -r requirements.txt

# %%
from utils import *
set_seed(42)
# Out:
# Device Selected: cuda

# %%
from datasets import CIFAR10
from torchvision import transforms
batch_size = 512
cifar10 = CIFAR10(batch_size)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
cifar10.show_examples()

# %%
from runner import Experiment
# Out:
# /usr/local/lib/python3.10/dist-packages/torch_lr_finder/lr_finder.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
from custom_resnet import Model

# %%
model = Model()
model.summary(input_size=(batch_size, 3, 32, 32))
# Out:
# ...
# Layer (type:depth-idx)                             Input Shape               Output Shape              Param #                   Param %
# ...
# Model                                              [512, 3, 32, 32]          [512, 10]                 --                             --
# ├─Sequential: 1-1                                  [512, 3, 32, 32]          [512, 10]                 --                             --
# │    └─CustomLayer: 2-1                            [512, 3, 32, 32]          [512, 64, 32, 32]         --                             --
# │    │    └─ConvLayer: 3-1                         [512, 3, 32, 32]          [512, 64, 32, 32]         --                             --
# │    │    │    └─Sequential: 4-1                   [512, 3, 32, 32]          [512, 64, 32, 32]         --                             --
# │    │    │    │    └─Conv2d: 5-1                  [512, 3, 32, 32]          [512, 64, 32, 32]         1,728                       0.03%
# ...

# %%
exp1 = Experiment(model, cifar10)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1.79E-04

# %%
exp1.execute()
# Out:
# Epoch: 1
# Train: Average Loss: 1.8969, Accuracy: 31.93 LR: 3.69142148205473e-05: 100%|██████████| 98/98 [00:28<00:00,  3.38it/s]
# Test:  Average loss: 1.4318, Accuracy: 49.12
# Epoch: 2
# Train: Average Loss: 1.3019, Accuracy: 53.60 LR: 7.240189934184633e-05: 100%|██████████| 98/98 [00:28<00:00,  3.40it/s]
# Test:  Average loss: 1.1453, Accuracy: 59.16
# Epoch: 3
# Train: Average Loss: 1.0752, Accuracy: 61.88 LR: 0.00010788958386314537: 100%|██████████| 98/98 [00:28<00:00,  3.48it/s]
# Test:  Average loss: 0.9867, Accuracy: 65.19
# Epoch: 4
# Train: Average Loss: 0.9146, Accuracy: 67.80 LR: 0.00014337726838444442: 100%|██████████| 98/98 [00:28<00:00,  3.41it/s]
# Test:  Average loss: 0.8602, Accuracy: 69.53
# Epoch: 5
# Train: Average Loss: 0.8006, Accuracy: 71.80 LR: 0.00017886495290574345: 100%|██████████| 98/98 [00:29<00:00,  3.33it/s]
# Test:  Average loss: 0.7269, Accuracy: 74.46
# Epoch: 6
# ...

# %%
exp1.train.plot_stats()

# %%
exp1.test.plot_stats()

# %%
exp1.show_incorrect()
# Out:
# Test:  Average loss: 0.3011, Accuracy: 89.89
